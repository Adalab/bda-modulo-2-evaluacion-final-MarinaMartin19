# %%
# Fase 1: Extracción de datos de películas.

import requests

import pandas as pd
import mysql.connector
from mysql.connector import Error

# %%
URL = 'https://beta.adalab.es/resources/apis/pelis/pelis.json'

datos = request.get(url)
datos.status_code
datos.content

datos_pelis = datos.json()

# %%
try: 
    cnx = mysql.connector.connect (
        host = '127.0.0.1',
        user = 'root',
        password = 'Amsterdam19'
    )

    print('Conexión exitosa')

except Error as e:
    print ('Error al conectar:', e)
# Out:
# Conexión exitosa

# %%
# Out:
# <function movies_data_json at 0x000001A127CACF40>
