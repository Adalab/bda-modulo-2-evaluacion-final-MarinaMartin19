# %%
import pandas as pd

# %%
import requests

# %%
# URL del API

url = 'https://beta.adalab.es/resources/apis/pelis/pelis.json'

# %%
# Hacemos la petición GET al API
response  = requests.get( 'https://beta.adalab.es/resources/apis/pelis/pelis.jso')

# %%
# Convertimos la respuesta a formato JSON

pelis_json = response.
